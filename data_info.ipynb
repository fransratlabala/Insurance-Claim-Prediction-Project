# %% [markdown]
# ## The dataset
#
# | Column | Description |
# |--------|-------------|
# | `id` | Unique client identifier |
# | `age` | Client's age: <br> <ul><li>`0`: 16-25</li><li>`1`: 26-39</li><li>`2`: 40-64</li><li>`3`: 65+</li></ul> |
# | `gender` | Client's gender: <br> <ul><li>`0`: Female</li><li>`1`: Male</li></ul> |
# | `driving_experience` | Years the client has been driving: <br> <ul><li>`0`: 0-9</li><li>`1`: 10-19</li><li>`2`: 20-29</li><li>`3`: 30+</li></ul> |
# | `education` | Client's level of education: <br> <ul><li>`0`: No education</li><li>`1`: High school</li><li>`2`: University</li></ul> |
# | `income` | Client's income level: <br> <ul><li>`0`: Poverty</li><li>`1`: Working class</li><li>`2`: Middle class</li><li>`3`: Upper class</li></ul> |
# | `credit_score` | Client's credit score (between zero and one) |
# | `vehicle_ownership` | Client's vehicle ownership status: <br><ul><li>`0`: Does not own their vehilce (paying off finance)</li><li>`1`: Owns their vehicle</li></ul> |
# | `vehcile_year` | Year of vehicle registration: <br><ul><li>`0`: Before 2015</li><li>`1`: 2015 or later</li></ul> |
# | `married` | Client's marital status: <br><ul><li>`0`: Not married</li><li>`1`: Married</li></ul> |
# | `children` | Client's number of children |
# | `postal_code` | Client's postal code |
# | `annual_mileage` | Number of miles driven by the client each year |
# | `vehicle_type` | Type of car: <br> <ul><li>`0`: Sedan</li><li>`1`: Sports car</li></ul> |
# | `speeding_violations` | Total number of speeding violations received by the client |
# | `duis` | Number of times the client has been caught driving under the influence of alcohol |
# | `past_accidents` | Total number of previous accidents the client has been involved in |
# | `outcome` | Whether the client made a claim on their car insurance (response variable): <br><ul><li>`0`: No claim</li><li>`1`: Made a claim</li></ul> |

# %% [markdown]
# 1. Overall Claim Rate
# - Question: What percentage of clients actually file claims?
# - EDA: Count how many rows have outcome = 1 vs. outcome = 0.
# - Business insight: Shows whether claims are rare (imbalanced dataset). If only ~10–20% claim, insurers know most policies are profitable but a small group drives costs.
#
# 2. Age & Driving Experience
# - Question: Do younger drivers or less experienced drivers claim more?
# - EDA: Group by age buckets (e.g., <25, 25–40, 40–60, 60+) and compare claim rates. Do the same for driving_experience categories.
# - Business insight: Helps insurers adjust premiums for high-risk age/experience groups.
#
# 3. Financial Profile
# - Question: Does income or credit score affect claim likelihood?
# - EDA:
# - Compare claim rates across income categories (poverty, working class, upper class).
# - Plot average credit_score for claim vs. no-claim groups.
# - Business insight: Insurers often use financial stability as a proxy for risk.
#
# 4. Vehicle Information
# - Question: Do certain cars lead to more claims?
# - EDA:
# - Compare claim rates by vehicle_year (before vs. after 2015).
# - Compare claim rates by vehicle_type (sedan, SUV, sports car).
# - Look at annual_mileage distribution for claim vs. no-claim.
# - Business insight: Guides underwriting — e.g., sports cars or high-mileage drivers may be riskier.
#
# 5. Risky Behaviors
# - Question: Do violations and past accidents predict claims?
# - EDA:
# - Compare claim rates by number of speeding_violations.
# - Compare claim rates for clients with duis = 1 vs. duis = 0.
# - Compare claim rates by past_accidents.
# - Business insight: Strong predictors of risk; insurers may penalize repeat offenders.
#
# 6. Family & Lifestyle
# - Question: Does marital status or having children affect claim rates?
# - EDA:
# - Compare claim rates for married = 1 vs. married = 0.
# - Compare claim rates by number of children.
# - Business insight: Married clients or those with children may drive more cautiously.
#
# 7. Feature Interactions
# - Question: Are there combinations that matter?
# - EDA:
# - Example: Young drivers with sports cars vs. older drivers with sedans.
# - Example: Low credit score + past accidents vs. high credit score + clean record.
# - Business insight: Helps insurers identify “high-risk profiles.”
#
# 🎯 Portfolio Presentation Tip
# When you present EDA:
# - Don’t just show charts — frame them as answers to business questions.
# - Example: “Drivers under 25 with less than 10 years of experience have a 2.5x higher claim rate.”
# - This makes your project look like business analytics + data science, not just raw statistics.
